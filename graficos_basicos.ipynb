# %% [markdown]
# <a href="https://colab.research.google.com/github/mobukerk/Data_Journey/blob/main/graficos_basicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

dias=["Lun","Mar","Mer","Gio","Ven"]
horas=[2,3,0,4,2]

plt.bar(dias,horas)
plt.title("Orari di studio della settimana")
plt.xlabel("Giorno")
plt.ylabel("Ora")
plt.show()
# Out:
# Text(0, 0.5, 'Ora')

# %%
import matplotlib.pyplot as plt

Giorni=["Lun","Mar","Mer","Gio","Ven"]
Ore=[2,3,0,4,2]

plt.bar(Giorni,Ore)
plt.title("Ore di studio della settimana")
plt.xlabel("Giorno")
plt.ylabel("Ora")
plt.show()
